# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

db = pd.read_csv("output/HydrodynamicProfile.dat",delimiter=" ")

plt.plot(db["pos_z"],db["velocity"])
plt.xlim(3,15)
plt.xticks(np.arange(3,16))
plt.ylim(-0.2,0.3)

# %%
plt.plot(db["pos_z"],db["velocity"])
# plt.xlim(3,15)
# plt.xticks(np.arange(3,16))
# plt.ylim(-0.2,0.3)

# %%
plt.plot(db["pos_z"],db["density"])
# plt.xlim(3,15)
# plt.xticks(np.arange(3,16))
# plt.ylim(-0.2,0.3)

# %%
plt.plot(db["pos_z"],db["temperature"])
# plt.xlim(3,15)
# plt.xticks(np.arange(3,16))
# plt.ylim(-0.2,0.3)
